# %% [markdown]
# # Plotting using nilearn

# %%
from nilearn.plotting import plot_roi, plot_stat, plot_glass_brain
# %matplotlib inline

# %%
plot_roi("/tmp/sub-10159_T1w_brain_mask.nii.gz", "/Users/rx/Documents/Research/my_fmriworkshop/fmri_workshop/data/sub-10159/anat/sub-10159_T1w.nii.gz",display_mode='y')

# %%
plot_stat_map("/Users/rx/Documents/Research/my_fmriworkshop/fmri_workshop/data/derivatives/task/sub-10159/lev2.gfeat/cope1.feat/thresh_zstat1.nii.gz", cut_coords=(-45, 3, 29))

# %%
plot_glass_brain("/Users/rx/Documents/Research/my_fmriworkshop/fmri_workshop/data/derivatives/task/sub-10159/lev2.gfeat/cope1.feat/thresh_zstat1.nii.gz", cut_coords=(-45, 3, 29))
